# %%
x=2

# %%
print(x)
# Out:
# 2

# %%
x=x+1
print(x)
# Out:
# 5

# %%
if x == 4:
    print("good")
else:
    print("bad")
# Out:
# bad

# %%
nums=[1,2,3,4,5]
for i in nums:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=0;
while i!=5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
